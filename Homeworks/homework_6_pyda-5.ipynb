# %% [markdown]
# # Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd
data = pd.read_csv('Python_6_pandas_basics/ml-20m/ratings.csv')

# %%
data.head()
# best_movies = data[ data.rating == 5]
data[ data.rating == 5]['movieId'].value_counts(normalize=True).head(1)
# Out:
# 318    0.011004
# Name: movieId, dtype: float64

# %% [markdown]
# # Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
def baltic(country):
    if country in ['Lithuania', 'Latvia', 'Estonia']:
        return 'baltic'
    return 'other'

data2 = pd.read_csv('Python_6_pandas_basics/power.csv')
data2['baltic'] = data2.country.apply(baltic)
data2_filter1 = data2[(data2.quantity >= 0) & 
                      (data2.baltic == 'baltic') & 
                      (data2.category.isin([4,12,21])) & 
                      (data2.year <= 2010) & (data2.year >= 2005)]
# data2.head()
# data2_filter1.head()
data2_filter1.quantity.sum()
# Out:
# 240580.0

# %% [markdown]
# # Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
data_html = pd.read_html('https://codificator.ru/code/mobile/', encoding='utf-8', na_values=['#НД'])

for i in range(len(data_html)):
    try:
        display(data_html[i].sort_values('Оператор').head())
        data_codes = data_html[i]
    except:
        display(data_html[i].head())
# Out:
#    №                                  Оператор                Коды  \
# 1  2                                      АКОС  902, 950, 952, 994
# 4  5                                     АПЕКС                 901
# 6  7                                      АСВТ                 997
# 0  1                            Аврора Телеком                 958
# 2  3  Акционерное общество Севастополь Телеком                 978
#
#   Всего номеров
# 1      620 тыс.
# 4       60 тыс.
# 6        2 млн.
# 0         10300
# 2       23 тыс.
#         Бренд                        Компания (юридическое лицо)  \
#         Бренд                                    Полное название
# 0      Билайн         Публичное акционерное общество «ВымпелКом»
# 1         МТС  Публичное акционерное общество «Мобильные Теле...
# 2       Теле2  Общество с ограниченной ответственностью «Т2 М...
# 3  СберМобайл  Общество с ограниченной ответственностью «Сбер...
#
#
#                                     Краткое название
# 0  ПАО «ВымпелКом»(входит в группу компаний VEON ...
# 1                                          ПАО «МТС»
# 2                                    ООО «Т2 Мобайл»
# 3                             ООО «Сбербанк-Телеком»

# %%
def find_operator(data, code):
    return data[data['Коды'].str.contains(code)]
    
find_operator(data_codes, '912')
# Out:
#      №    Оператор                                               Коды  \
# 44  45         МТС  901, 902, 904, 908, 910, 911, 912, 913, 914, 9...
# 53  54  Ростелеком  901, 902, 912, 930, 939, 955, 958, 970, 971, 9...
#
#    Всего номеров
# 44      171 млн.
# 53        7 млн.

# %%
import pandas as pd
data_html = pd.read_html('https://www.moesk.ru/client/disconnection/#tab-planovie-otkluchenia', encoding='utf-8', na_values=['#НД'])
for i in range(len(data_html)):
        display(data_html[i].head(10))
# Out:
#       Филиал  (РЭС, район МКС)  \
#       Филиал  (РЭС, район МКС)
# 0  Северные электрические сети
# 1      СЭС,  Красногорский РЭС
# 2    СЭС,  Солнечногорский РЭС
# 3    СЭС,  Солнечногорский РЭС
# 4    СЭС,  Солнечногорский РЭС
# 5    СЭС,  Солнечногорский РЭС
# 6    СЭС,  Солнечногорский РЭС
# 7    СЭС,  Солнечногорский РЭС
# 8    СЭС,  Солнечногорский РЭС
# 9    СЭС,  Солнечногорский РЭС
#
#                               Административный район  \
#                               Административный район
# 0                        Северные электрические сети
# 1  Красногорский район - административный центр -...
# 2  Солнечногорский район - административный центр...
# 3  Солнечногорский район - административный центр...
# 4  Солнечногорский район - административный центр...
# 5  Солнечногорский район - административный центр...
# 6  Солнечногорский район - административный центр...
# 7  Солнечногорский район - административный центр...
# 8  Солнечногорский район - административный центр...
# 9  Солнечногорский район - административный центр...
#
#                             Отключаемые  потребители  \
#                             Отключаемые  потребители
# 0                        Северные электрические сети
# 1                                        д. Ангелово
# 2                                         д. Обухово
# 3                         д. Поярково,  д. Владычино
# 4  д. Вельево,  д. Мерзлово,  д. Тимоново,  д. Бе...
# 5                    п. Красный Воин,  п. Менделеево
# 6                                        д. Соколово
# 7                                         д. Березки
# 8                                   Алабушево (село)
# 9                                    Алабушево(село)
#
#                          Время                               \
#                         Начало                        Конец
# 0  Северные электрические сети  Северные электрические сети
# 1                        09:00                        17:00
# 2                        08:00                        17:00
# 3                        08:00                        17:00
# 4                        08:00                        17:00
# 5                        10:00                        16:00
# 6                        08:00                        17:00
# 7                        08:00                        17:00
# 8                        08:00                        17:00
# 9                        08:00                        17:00
#
#                            Отключаемое  оборудование  \
#                            Отключаемое  оборудование
# 0                        Северные электрические сети
# 1                                  КТП-1002 РУ-0.4кВ
# 2                      ТП-887 РУ-0.4кВ ф. 2 откл. АВ
# 3  РТП-131 кратковременно 2 раза ВВ яч ЛР- 1089, ...
# 4  ЦРП-41 яч ф. Бедово МВ,  КРотключить ТП-816 яч...
# 5                                     РП-95 1 секция
# 6  откл ВВК откл КР ТП-536 яч. Волна,  откл ВВК о...
# 7                          КТП-522 главный рубильник
# 8                      ТП-470 РУ-0.4кВ откл. АВ ф. 1
# 9                     КТП-432 РУ-0.4кВ откл. АВ ф. 1
#
#                                  Наименование  работ
#                                  Наименование  работ
# 0                        Северные электрические сети
# 1  КТП-1002 РУ-0.4кВ расшиновка и перезаводка отх...
# 2                Замена опор,  провода ВЛ-0.4кВ ф. 2
# 3         Ревизия ВПР КТП-1227,  кап ремонт КТП-1227
# 4  ВЛ-10кВ ф. Бедово оп №139,  140оп №139 ревизия...
# 5                                   Монтаж яч. РП--3
# 6  замена опор №3, 5, 6, 7; замена провода в прол...
# 7  Замена водов,  монтаж контуров заземления ВЛ-0...
# 8       Капитальный ремонт ВЛ-0.4кВ (замена провода)
# 9       Капитальный ремонт ВЛ-0.4кВ (Замена провода)
#    Филиал  (РЭС, район МКС)  \
#    Филиал  (РЭС, район МКС)
# 0  Южные электрические сети
# 1      ЮЭС,  Ступинский РЭС
# 2      ЮЭС,  Ступинский РЭС
# 3      ЮЭС,  Ступинский РЭС
# 4      ЮЭС,  Ступинский РЭС
# 5    ЮЭС,  Серпуховский РЭС
# 6    ЮЭС,  Серпуховский РЭС
# 7   ЮЭС,  Домодедовский РЭС
# 8   ЮЭС,  Домодедовский РЭС
# 9   ЮЭС,  Домодедовский РЭС
#
#                               Административный район  \
#                               Административный район
# 0                           Южные электрические сети
# 1  Ступинский район - административный центр - го...
# 2  Ступинский район - административный центр - го...
# 3  Ступинский район - административный центр - го...
# 4  Ступинский район - административный центр - го...
# 5  Серпуховский район - административный центр - ...
# 6  Серпуховский район - административный центр - ...
# 7                                   город Домодедово
# 8                                   город Домодедово
# 9                                   город Домодедово
#
#                             Отключаемые  потребители  \
#                             Отключаемые  потребители
# 0                           Южные электрические сети
# 1                                          д. Мясное
# 2                        д. Авдотьино,  д. Мышенское
# 3  д. Колычево,  д. Мышенское,  д. Теняково,  д. ...
# 4  д. Глебово,  д. Щапово,  с. Хонятино,  д. Пест...
# 5                                         д. Агарино
# 6                                        д. Борисово
# 7                                                NaN
# 8                                          д. Жуково
# 9                                              с. Ям
#
#                       Время                            \
#                      Начало                     Конец
# 0  Южные электрические сети  Южные электрические сети
# 1                     10:00                     15:00
# 2                     10:00                     12:00
# 3                     08:00                     17:00
# 4                     08:00                     17:00
# 5                     08:00                     17:00
# 6                     08:00                     17:00
# 7                     09:00                     16:00
# 8                     09:00                     16:00
# 9                     09:00                     17:00
#
#              Отключаемое  оборудование  \
#              Отключаемое  оборудование
# 0             Южные электрические сети
# 1               ВЛ-10кВ фид. 12 ПС-529
# 2                ВЛ-10кВ фид. 3 ПС-274
# 3                 ВЛ-10кВ фид. 1 РП- 1
# 4            ВЛ-10кВ фид. 5 от ЗТП-475
# 5  ВЛ-10кВ фид. с ТП-225 на мостопоезд
# 6                   БМКТП-899 РУ-0.4кВ
# 7                КЛ-10кВ фид. 9 с РП-6
# 8                              КТП-984
# 9                      КТП-34 РУ-0.4кВ
#
#                           Наименование  работ
#                           Наименование  работ
# 0                    Южные электрические сети
# 1             по заявке абонента КТП-1038 АЗС
# 2                       подключение новой ТП-
# 3    по заявке абонента КТП-335 о/л "Дельфин"
# 4  по заявке абонента КТП-1092 для ремонта ЛР
# 5            Установка КТП-в охранной зоне ВЛ
# 6                 Текущий ремонт БМКТП-без ВР
# 7                              врезка КРН-105
# 8   покраска КТП-,  замена гл. руб в РУ-0.4кВ
# 9                         монтаж н/в доп. авт
#        Филиал  (РЭС, район МКС)  \
#        Филиал  (РЭС, район МКС)
# 0  Восточные электрические сети
# 1         ВЭС,  Егорьевский РЭС
# 2         ВЭС,  Егорьевский РЭС
# 3         ВЭС,  Егорьевский РЭС
# 4         ВЭС,  Егорьевский РЭС
# 5         ВЭС,  Егорьевский РЭС
# 6         ВЭС,  Егорьевский РЭС
# 7         ВЭС,  Егорьевский РЭС
# 8         ВЭС,  Егорьевский РЭС
# 9         ВЭС,  Егорьевский РЭС
#
#                               Административный район  \
#                               Административный район
# 0                       Восточные электрические сети
# 1  Егорьевский район - административный центр - г...
# 2  Егорьевский район - административный центр - г...
# 3  Егорьевский район - административный центр - г...
# 4  Егорьевский район - административный центр - г...
# 5  Егорьевский район - административный центр - г...
# 6  Егорьевский район - административный центр - г...
# 7  Егорьевский район - административный центр - г...
# 8  Егорьевский район - административный центр - г...
# 9  Егорьевский район - административный центр - г...
#
#        Отключаемые  потребители                         Время  \
#        Отключаемые  потребители                        Начало
# 0  Восточные электрические сети  Восточные электрические сети
# 1                      Никоново                         10:00
# 2                       Саввино                         10:00
# 3                         Жабки                         10:00
# 4                     Голубевая                         10:00
# 5                       Анненка                         10:00
# 6                        Двойни                         10:00
# 7                        Двойни                         10:00
# 8                     Поповская                         10:00
# 9                       Починки                         10:00
#
#                                      Отключаемое  оборудование  \
#                           Конец      Отключаемое  оборудование
# 0  Восточные электрические сети   Восточные электрические сети
# 1                         17:00   ВЛ-0.4кВ от МТП-107 Никоново
# 2                         17:00    ВЛ-0.4кВ от ЗТП-175 Саввино
# 3                         17:00      ВЛ-0.4кВ от ЗТП-104 Жабки
# 4                         17:00  ВЛ-0.4кВ от КТП-111 Голубевая
# 5                         17:00                МТП-428 Анненка
# 6                         17:00     ВЛ-0.4кВ от МТП-320 Двойни
# 7                         17:00     ВЛ-0.4кВ от МТП-148 Двойни
# 8                         17:00              ЗТП-685 Поповская
# 9                         17:00                ЗТП-101 Починки
#
#              Наименование  работ
#              Наименование  работ
# 0   Восточные электрические сети
# 1  Технологические присоединения
# 2  Технологические присоединения
# 3  Технологические присоединения
# 4  Технологические присоединения
# 5  Технологические присоединения
# 6    Капитальный ремонт ВЛ-0.4кВ
# 7    Капитальный ремонт ВЛ-0.4кВ
# 8         Капитальный ремонт ТП-
# 9         Капитальный ремонт ТП-
#       Филиал  (РЭС, район МКС)  \
#       Филиал  (РЭС, район МКС)
# 0  Западные электрические сети
# 1          ЗЭС,  Можайский РЭС
# 2          ЗЭС,  Успенский РЭС
# 3      ЗЭС,  Волоколамский РЭС
# 4      ЗЭС,  Волоколамский РЭС
# 5      ЗЭС,  Волоколамский РЭС
# 6      ЗЭС,  Волоколамский РЭС
# 7      ЗЭС,  Волоколамский РЭС
# 8      ЗЭС,  Волоколамский РЭС
# 9      ЗЭС,  Волоколамский РЭС
#
#                               Административный район  \
#                               Административный район
# 0                        Западные электрические сети
# 1  Можайский район - административный центр - гор...
# 2  Одинцовский район - административный центр - г...
# 3  Волоколамский район - административный центр -...
# 4  Волоколамский район - административный центр -...
# 5  Волоколамский район - административный центр -...
# 6  Волоколамский район - административный центр -...
# 7  Волоколамский район - административный центр -...
# 8  Волоколамский район - административный центр -...
# 9  Волоколамский район - административный центр -...
#
#                             Отключаемые  потребители  \
#                             Отключаемые  потребители
# 0                        Западные электрические сети
# 1              д. Еремеево,  д. Кожино,  д. Наречино
# 2                                      с. Знаменское
# 3                                      д. Ивановское
# 4                                         д. Тимково
# 5                                        с. Осташево
# 6                                       д. Курьяново
# 7                                       д. Судниково
# 8                                           д. Спасс
# 9  д. Спасс-Помазкино,  с. Ярополец,  д. Гарутино...
#
#                          Время                               \
#                         Начало                        Конец
# 0  Западные электрические сети  Западные электрические сети
# 1                        08:00                        17:00
# 2                        08:00                        17:00
# 3                        08:00                        17:00
# 4                        10:00                        17:00
# 5                        09:00                        17:00
# 6                        09:00                        17:00
# 7                        09:00                        14:00
# 8                        09:00                        17:00
# 9                        08:00                        17:00
#
#                           Отключаемое  оборудование  \
#                           Отключаемое  оборудование
# 0                       Западные электрические сети
# 1         ВЛ-10кВ фид 8 ПС-428 от ТП-1095 до ТП-430
# 2  ВЛ-0.4кВ от ТП-6746 направление опор № 1 магазин
# 3                           МТП-4357  д. Ивановское
# 4                              МТП-1118  д. Тимково
# 5  ВЛ-0.4кВ фид ул. Новая,  ул. Полевая от КТП-1257
# 6                ВЛ-0.4кВ фид деревня от КТП-П 1482
# 7                         КТП-П 1280 Судниково клуб
# 8                           ЗТП-1281 Спас "Надежда"
# 9                           ВЛ-10кВ фид 6 с ПС-Лама
#
#                                 Наименование  работ
#                                 Наименование  работ
# 0                       Западные электрические сети
# 1                                    Монтаж провода
# 2               Замена провода в пролете опор № 2-5
# 3                        монтаж системы мониторинга
# 4                              ревизия оборудования
# 5                                работа на ВЛ-0.4кВ
# 6                            реконструкция ВЛ-0.4кВ
# 7                    замена рур. фид магазин,  клуб
# 8            опробование АВР в полной схеме (5 сек)
# 9  замена КТП-1086 на МТП-,  включение по программе
#        Филиал  (РЭС, район МКС)     Административный район  \
#        Филиал  (РЭС, район МКС)     Административный район
# 0                  Новая Москва               Новая Москва
# 1    Новая Москва(Троицкий РЭС)  Поселение Краснопахорское
# 2    Новая Москва(Троицкий РЭС)       Поселение Кленовское
# 3    Новая Москва(Троицкий РЭС)  Поселение Краснопахорское
# 4  Новая Москва(Московский РЭС)     Поселение Марушкинское
# 5  Новая Москва(Московский РЭС)     Поселение Первомайское
# 6    Новая Москва(Троицкий РЭС)  Поселение Новофедоровское
#
#                             Отключаемые  потребители         Время  \
#                             Отключаемые  потребители        Начало
# 0                                       Новая Москва  Новая Москва
# 1                                      Красная Пахра         09:00
# 2                                            Кленово         09:00
# 3                                             Былово         09:00
# 4                                      д. Кривошеино         09:00
# 5                                            Клоково         09:00
# 6  Руднево,  Кузнецово,  Федоровское,  Новиково, ...         09:00
#
#                 Отключаемое  оборудование  \
#           Конец Отключаемое  оборудование
# 0  Новая Москва              Новая Москва
# 1         17:00                   КТП-870
# 2         17:00     КВЛ-6кВ ф. 8 с ПС-524
# 3         17:00                   КТП-636
# 4         17:00                  КТП-1471
# 5         17:00      РУ-0.4кВ от КТП-1323
# 6         17:00     КВЛ-10кВ ф.12 с РП-4н
#
#                                  Наименование  работ
#                                  Наименование  работ
# 0                                       Новая Москва
# 1                            Капитальный ремонт КТП-
# 2  ТП-696 регулировка привода ЗН в ячейке ввода ф...
# 3                       Капитальный ремонт ВЛ-0.4кВ.
# 4                                        Замена КТП-
# 5                              Замена приборов учета
# 6  По заявке ООО "Кумир" для ремонта выносного ра...
#     Филиал  (РЭС, район МКС)     Административный район  \
#     Филиал  (РЭС, район МКС)     Административный район
# 0  Московские кабельные сети  Московские кабельные сети
# 1                  9 РЭР МКС             Район Северный
#
#     Отключаемые  потребители                      Время  \
#     Отключаемые  потребители                     Начало
# 0  Московские кабельные сети  Московские кабельные сети
# 1                        NaN                      09:00
#
#                               Отключаемое  оборудование  \
#                        Конец  Отключаемое  оборудование
# 0  Московские кабельные сети  Московские кабельные сети
# 1                      16:00                  ТП-21613Б
#
#                 Наименование  работ
#                 Наименование  работ
# 0         Московские кабельные сети
# 1  Реконструкция КЛ 0.4кВ вв. Аб-та
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0         Северные электрические сети         Северные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0         Северные электрические сети         Северные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0         Северные электрические сети         Северные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0         Северные электрические сети
# 1  Плановые отключения не планируются
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0            Южные электрические сети            Южные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0            Южные электрические сети            Южные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0            Южные электрические сети            Южные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0            Южные электрические сети
# 1  Плановые отключения не планируются
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0        Восточные электрические сети        Восточные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0        Восточные электрические сети        Восточные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0        Восточные электрические сети        Восточные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0        Восточные электрические сети
# 1  Плановые отключения не планируются
#       Филиал  (РЭС, район МКС)  \
#       Филиал  (РЭС, район МКС)
# 0  Западные электрические сети
# 1     ЗЭС,  Наро-Фоминский РЭС
# 2     ЗЭС,  Наро-Фоминский РЭС
# 3     ЗЭС,  Наро-Фоминский РЭС
# 4     ЗЭС,  Наро-Фоминский РЭС
# 5     ЗЭС,  Наро-Фоминский РЭС
# 6     ЗЭС,  Наро-Фоминский РЭС
# 7     ЗЭС,  Наро-Фоминский РЭС
# 8     ЗЭС,  Наро-Фоминский РЭС
#
#                               Административный район  \
#                               Административный район
# 0                        Западные электрические сети
# 1  Наро-Фоминский район - административный центр ...
# 2  Наро-Фоминский район - административный центр ...
# 3  Наро-Фоминский район - административный центр ...
# 4  Наро-Фоминский район - административный центр ...
# 5  Наро-Фоминский район - административный центр ...
# 6  Наро-Фоминский район - административный центр ...
# 7  Наро-Фоминский район - административный центр ...
# 8  Наро-Фоминский район - административный центр ...
#
#       Отключаемые  потребители                        Время  \
#       Отключаемые  потребители                       Начало
# 0  Западные электрические сети  Западные электрические сети
# 1                с. Петровское                        09:00
# 2                   д. Софьино                        09:00
# 3                   д. Софьино                        09:00
# 4                  с. Атепцево                        09:00
# 5                 с. Каменское                        09:00
# 6                 д. Симбухово                        09:00
# 7                 д. Симбухово                        09:00
# 8                д. Золотьково                        09:00
#
#                                        Отключаемое  оборудование  \
#                          Конец         Отключаемое  оборудование
# 0  Западные электрические сети       Западные электрические сети
# 1                        17:00    ТП-1449 ВЛ-0.4кВ фид. 3 оп. 16
# 2                        17:00   ТП-1358 ВЛ-0.4кВ фид. 1 оп. 9/2
# 3                        17:00  ТП-1358 ВЛ-0.4кВ фид. 1 оп. 18/1
# 4                        17:00   ТП-280 ВЛ-0.4кВ фид. 1 оп. 22/1
# 5                        17:00     ТП-147 ВЛ-0.4кВ фид. 1 оп. 14
# 6                        17:00          ТП-1111 фид. Дачи оп. 53
# 7                        17:00  ТП-1111 фид. Дер. пр. ст. оп. 25
# 8                        17:00        ТП-789 фид. Деревня оп. 12
#
#                       Наименование  работ
#                       Наименование  работ
# 0             Западные электрические сети
# 1  Новое включение уч. 50:206:0210101:397
# 2  Новое включение уч. 50:206:0151418:190
# 3                   Новое включение уч. №
# 4                 Новое включение уч. 157
# 5                  Новое включение уч. 43
# 6   Новое включение уч. 50:206:0031402:24
# 7                  Новое включение уч. 17
# 8  Новое включение уч. 50:206:0030802:445
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0                        Новая Москва                        Новая Москва
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0                        Новая Москва                        Новая Москва
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0                        Новая Москва                        Новая Москва
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0                        Новая Москва
# 1  Плановые отключения не планируются
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0           Московские кабельные сети           Московские кабельные сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0           Московские кабельные сети           Московские кабельные сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0           Московские кабельные сети           Московские кабельные сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0           Московские кабельные сети
# 1  Плановые отключения не планируются
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0         Северные электрические сети         Северные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0         Северные электрические сети         Северные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0         Северные электрические сети         Северные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0         Северные электрические сети
# 1  Плановые отключения не планируются
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0            Южные электрические сети            Южные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0            Южные электрические сети            Южные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0            Южные электрические сети            Южные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0            Южные электрические сети
# 1  Плановые отключения не планируются
#        Филиал  (РЭС, район МКС)  \
#        Филиал  (РЭС, район МКС)
# 0  Восточные электрические сети
# 1    ВЭС,  Орехово-Зуевский РЭС
# 2    ВЭС,  Орехово-Зуевский РЭС
# 3    ВЭС,  Орехово-Зуевский РЭС
#
#                               Административный район  \
#                               Административный район
# 0                       Восточные электрические сети
# 1  Орехово-Зуевский район - административный цент...
# 2  Орехово-Зуевский район - административный цент...
# 3  Орехово-Зуевский район - административный цент...
#
#        Отключаемые  потребители                         Время  \
#        Отключаемые  потребители                        Начало
# 0  Восточные электрические сети  Восточные электрические сети
# 1                 д. Столбуново                         09:00
# 2                   д. Понарино                         08:30
# 3                    д. Мисцево                         08:30
#
#                                                  Отключаемое  оборудование  \
#                           Конец                  Отключаемое  оборудование
# 0  Восточные электрические сети               Восточные электрические сети
# 1                         18:00                       ВЛ-0.4кВ от МТП-1243
# 2                         17:00  ВЛ-10кВ РП-1013-ТП-1039 оТП-. на МТП-1522
# 3                         17:00                       ВЛ-0.4кВ от МТП-1642
#
#                             Наименование  работ
#                             Наименование  работ
# 0                  Восточные электрические сети
# 1       1. Расчистка трасы. 2 Перетяжка провода
# 2  1. Установка доп. опоры 2 Перетяжка провода.
# 3            1. Замена опор 2 Перетяжка провода
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0         Западные электрические сети         Западные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0         Западные электрические сети         Западные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0         Западные электрические сети         Западные электрические сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0         Западные электрические сети
# 1  Плановые отключения не планируются
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0                        Новая Москва                        Новая Москва
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0                        Новая Москва                        Новая Москва
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0                        Новая Москва                        Новая Москва
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0                        Новая Москва
# 1  Плановые отключения не планируются
#              Филиал  (РЭС, район МКС)              Административный район  \
#              Филиал  (РЭС, район МКС)              Административный район
# 0           Московские кабельные сети           Московские кабельные сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#              Отключаемые  потребители                               Время  \
#              Отключаемые  потребители                              Начало
# 0           Московские кабельные сети           Московские кабельные сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                                                 Отключаемое  оборудование  \
#                                 Конец           Отключаемое  оборудование
# 0           Московские кабельные сети           Московские кабельные сети
# 1  Плановые отключения не планируются  Плановые отключения не планируются
#
#                   Наименование  работ
#                   Наименование  работ
# 0           Московские кабельные сети
# 1  Плановые отключения не планируются
#   Регион РФ (область, край, город фед. значения, округ)  \
# 0         Химкинский р-н, Химки г.о. Московская обл.
# 1         Химкинский р-н, Химки г.о. Московская обл.
# 2         Химкинский р-н, Химки г.о. Московская обл.
# 3         Химкинский р-н, Химки г.о. Московская обл.
# 4         Химкинский р-н, Химки г.о. Московская обл.
# 5         Химкинский р-н, Химки г.о. Московская обл.
# 6         Химкинский р-н, Химки г.о. Московская обл.
# 7         Химкинский р-н, Химки г.о. Московская обл.
# 8         Химкинский р-н, Химки г.о. Московская обл.
# 9         Химкинский р-н, Химки г.о. Московская обл.
#
#    Административный район Населённыйпункт Улица Дата  Время Дата.1 Время.1  \
# 0  Клязьма-Старбеево мкр.               −     −   05  09:00     05   16:00
# 1  Клязьма-Старбеево мкр.               −     −   06  09:00     06   16:00
# 2  Клязьма-Старбеево мкр.               −     −   07  09:00     07   16:00
# 3  Клязьма-Старбеево мкр.               −     −   08  09:00     08   16:00
# 4  Клязьма-Старбеево мкр.               −     −   09  09:00     09   16:00
# 5  Клязьма-Старбеево мкр.               −     −   12  09:00     12   16:00
# 6  Клязьма-Старбеево мкр.               −     −   13  09:00     13   16:00
# 7  Клязьма-Старбеево мкр.               −     −   14  09:00     14   16:00
# 8  Клязьма-Старбеево мкр.               −     −   15  09:00     15   16:00
# 9  Клязьма-Старбеево мкр.               −     −   16  09:00     16   16:00
#
#         Филиал             РЭС
# 0  ПАО "МОЭСК"  Химкинский РЭС
# 1  ПАО "МОЭСК"  Химкинский РЭС
# 2  ПАО "МОЭСК"  Химкинский РЭС
# 3  ПАО "МОЭСК"  Химкинский РЭС
# 4  ПАО "МОЭСК"  Химкинский РЭС
# 5  ПАО "МОЭСК"  Химкинский РЭС
# 6  ПАО "МОЭСК"  Химкинский РЭС
# 7  ПАО "МОЭСК"  Химкинский РЭС
# 8  ПАО "МОЭСК"  Химкинский РЭС
# 9  ПАО "МОЭСК"  Химкинский РЭС
#    № п/п  Филиал ЭС  Район ЭС  Время отключения  \
# 0      1  ФИЛИАЛ ЭС  РАЙОН ЭС               NaN
#
#         Обесточенные потребители  Восстановительные работы
# 0  ОБЕСТОЧЕННЫХ ПОТРЕБИТЕЛЕЙ НЕТ                       NaN
